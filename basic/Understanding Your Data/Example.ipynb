# %% [markdown]
# # here using to slove the Univariate Analysis

# %%
import pandas as pd
import numpy as np

# %%
Univariate_data = pd.read_csv('4th Sem Attendance .csv')
Univariate_data.sample(5)
# here using the sample data (sample mean ----> random data form dataframe)
# Out:
#    BRCM COLLEGE OF ENGINEERING & TECHNOLOGY         Unnamed: 1  Unnamed: 2  \
# 68                              22-CSE-4988              UDIT   2210031036
# 9                               22-CSE-4925             ADITI   2210031107
# 38                              22-CSE-4932            MUSKAN   2210031022
# 31                              22-CSE-4961  MANAS KUMAR ARJYA  2210031124
# 11                              22-CSE-4944     AMRENDER KUMAR  2210031015
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 68          6         25          2       8.33          8      36.36
# 9          22      91.67         22      91.67         20      90.91
# 38         17      70.83         18         75         20      90.91
# 31         15       62.5         13      54.17         13      59.09
# 11         22      91.67         22      91.67         18      81.82
#
#    Unnamed: 9  ... Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...
