# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.figure(figsize = (14,6))
sns.scatterplot(x = 'cgpa',y= 'package',data = df,color = 'g')
plt.show()

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state  = 2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [160 rows x 1 columns]

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1))
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09324469])

# %%
# here now seeing the best fited lines in the datafrme 
# whcih has the less form of square of error 
plt.figure(figsize = (14,6))
plt.plot(x_train,lr.predict(x_train),color = 'r')
sns.scatterplot(x = 'cgpa',y= 'package',data = df,color = 'g')
plt.show()

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# -0.8961119222429144

# %%
# y = mx +b 
m * 8.58 + b
# Out:
# array([3.89111601])

# %%
# here in our data we dont's have the values aslo we can hvae we have 
m * 100 + b
# Out:
# array([54.89908542])
